# %%
import pandas as pd

df = pd.read_csv("../../Merge/final_selected_data.csv")
df.drop(columns=["room_type_id", "hotel_id", "room_room_type_name", "hotel_name", "hotel_address"], inplace=True, errors='ignore')
luxury_df = df[df["price_option_price"] < 2_000_000]

# %%
numerical_cols = [
    'flexibility_score', 'sqm', 'bathroom_count', 
    'bedroom_count', 'adults_number', 'children_number'
]

# %%
luxury_min_values = luxury_df[numerical_cols].max()

# %%
luxury_min_values
# Out:
# flexibility_score       5.0
# sqm                  6000.0
# bathroom_count         16.0
# bedroom_count          15.0
# adults_number          50.0
# children_number         9.0
# dtype: float64
